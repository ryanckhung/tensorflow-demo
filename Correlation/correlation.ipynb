# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.DataFrame()
df['index'] = range(0,50)

# %%
df['eq1'] = df['index'].apply(lambda x: 0.5*x + np.random.random()*10)
df['eq2'] = df['index'].apply(lambda x: -0.77*x + np.random.random())
df['eq3'] = df['index'].apply(lambda x: np.random.random())

# %%
df
# Out:
#     index        eq1        eq2       eq3
# 0       0   8.702159   0.055028  0.060448
# 1       1   8.082284  -0.023908  0.232651
# 2       2  10.518730  -0.961293  0.025028
# 3       3   8.570609  -1.910214  0.207010
# 4       4   6.953585  -2.702817  0.615429
# 5       5   5.410381  -3.689429  0.653267
# 6       6   5.993374  -4.249147  0.412076
# 7       7   4.652395  -5.171298  0.055629
# 8       8  11.857537  -5.613212  0.300516
# 9       9  13.504432  -6.055550  0.256187
# 10     10   7.848689  -7.509255  0.543375
# 11     11   6.097881  -7.937382  0.553189
# 12     12   6.739454  -8.845238  0.036612
# 13     13   7.755885  -9.215560  0.537318
# 14     14  13.155449 -10.278799  0.184465
# 15     15   8.015087 -10.629515  0.795764
# 16     16  16.066372 -12.233325  0.483443
# 17     17  13.037509 -12.997654  0.220656
# 18     18  12.982754 -13.152235  0.081125
# 19     19  10.316982 -14.012284  0.291597
# 20     20  17.820250 -14.772780  0.660941
# 21     21  16.195528 -15.904082  0.407183
# 22     22  13.928940 -16.333291  0.610361
# 23     23  15.653395 -16.968586  0.520422
# 24     24  18.783336 -17.814862  0.000045
# 25     25  14.872599 -18.540808  0.501226
# 26     26  19.624913 -19.088375  0.118463
# 27     27  17.118918 -20.384764  0.146269
# 28     28  19.105816 -20.808244  0.774527
# 29     29  17.669786 -21.338442  0.517367
# 30     30  22.336090 -23.073549  0.375407
# 31     31  23.842198 -23.514799  0.345764
# 32     32  18.173485 -24.052815  0.843645
# 33     33  22.736418 -24.444403  0.015219
# 34     34  17.533182 -25.701217  0.562908
# 35     35  23.868684 -26.337158  0.459798
# 36     36  22.010137 -27.672602  0.764764
# 37     37  23.790623 -27.911377  0.634860
# 38     38  20.150183 -28.631450  0.554817
# 39     39  23.761448 -29.227685  0.996581
# 40     40  22.685104 -29.985857  0.304843
# 41     41  25.971514 -31.448230  0.307885
# 42     42  24.546834 -31.391438  0.269667
# 43     43  30.931334 -32.274728  0.714443
# 44     44  29.504078 -33.318974  0.396604
# 45     45  27.980405 -34.617279  0.528519
# 46     46  27.220749 -35.391440  0.865893
# 47     47  27.350560 -35.764853  0.925273
# 48     48  25.261521 -36.547076  0.691721
# 49     49  32.559791 -36.877012  0.121874

# %%
df = df.drop(columns=['index'])
f = plt.figure(figsize=(10, 10))
plt.matshow(df.corr(), fignum=f.number)
plt.xticks(range(df.shape[1]), df.columns, fontsize=14, rotation=45)
plt.yticks(range(df.shape[1]), df.columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=12)

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_7b84a62a_287e_11eb_9613_dca9046d641crow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_7b84a62a_287e_11eb_9613_dca9046d641crow0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_7b84a62a_287e_11eb_9613_dca9046d641crow0_col2 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_7b84a62a_287e_11eb_9613_dca9046d641crow1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_7b84a62a_287e_11eb_9613_dca9046d641crow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_7b84a62a_287e_11eb_9613_dca9046d641crow1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_7b84a62a_287e_11eb_9613_dca9046d641crow2_col0 {
#             background-color:  #f3c8b2;
#             color:  #000000;
#         }    #T_7b84a62a_287e_11eb_9613_dca9046d641crow2_col1 {
#             background-color:  #9bbcff;
#             color:  #000000;
#         }    #T_7b84a62a_287e_11eb_9613_dca9046d641crow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_7b84a62a_287e_11eb_9613_dca9046d641c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >eq1</th>        <th class="col_heading level0 col1" >eq2</th>        <th class="col_heading level0 col2" >eq3</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7b84a62a_287e_11eb_9613_dca9046d641clevel0_row0" class="row_heading level0 row0" >eq1</th>
#                         <td id="T_7b84a62a_287e_11eb_9613_dca9046d641crow0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_7b84a62a_287e_11eb_9613_dca9046d641crow0_col1" class="data row0 col1" >-0.936738</td>
#                         <td id="T_7b84a62a_287e_11eb_9613_dca9046d641crow0_col2" class="data row0 col2" >0.245580</td>
#             </tr>
#             <tr>
#                         <th id="T_7b84a62a_287e_11eb_9613_dca9046d641clevel0_row1" class="row_heading level0 row1" >eq2</th>
#                         <td id="T_7b84a62a_287e_11eb_9613_dca9046d641crow1_col0" class="data row1 col0" >-0.936738</td>
#                         <td id="T_7b84a62a_287e_11eb_9613_dca9046d641crow1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_7b84a62a_287e_11eb_9613_dca9046d641crow1_col2" class="data row1 col2" >-0.369953</td>
#             </tr>
#             <tr>
#                         <th id="T_7b84a62a_287e_11eb_9613_dca9046d641clevel0_row2" class="row_heading level0 row2" >eq3</th>
#                         <td id="T_7b84a62a_287e_11eb_9613_dca9046d641crow2_col0" class="data row2 col0" >0.245580</td>
#                         <td id="T_7b84a62a_287e_11eb_9613_dca9046d641crow2_col1" class="data row2 col1" >-0.369953</td>
#                         <td id="T_7b84a62a_287e_11eb_9613_dca9046d641crow2_col2" class="data row2 col2" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
pd.plotting.scatter_matrix(df, figsize=(10, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbaf64ed340>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbaf6527280>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbaf8c0d700>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbaf9c99b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbaf9cc5fa0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbaf9cff370>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fbaf9cff460>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbaf9d29910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbaf6537160>]],
#       dtype=object)
